# %% [markdown]
# # Welcome to LearnLab Bridge
#
# This is your interactive Data Science environment.
#
# ### Getting Started
# 1. You can write Python code in the cells below.
# 2. All files saved in this folder are accessible outside the container in `./jupyter/notebooks`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Hello Data Science!")
# Out:
# Hello Data Science!
